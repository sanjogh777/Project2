# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was separated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were separated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# C:\Users\sanjo\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\io\parsers.py:702: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 5485           0.278561          -0.027365          -0.128601
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 5485         -0.999218         -0.972576         -0.966326           -0.9994
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 5485         -0.973144         -0.962837         -0.944042  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 5485                     0.000776                             -0.120776
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 5485                          0.009461                              -0.88854
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 5485             -0.857924              0.167397             -0.055168
#
#       subject  Activity  ActivityName
# 5485       26         5      STANDING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1145           0.201274           0.012434          -0.178199
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1145         -0.272197         -0.314587         -0.241232         -0.347018
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1145         -0.341021         -0.211422           0.06354  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1145                     0.371003                             -0.804003
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1145                         -0.973997                              0.729365
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1145             -0.881155              0.057491             -0.059623
#
#       subject  Activity  ActivityName
# 1145       10         1       WALKING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train['ActivityName'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
'''
Just making the column names more readable.
'''

columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down), motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple"))
plt.show()
# Out:
# C:\Users\sanjo\Anaconda3\envs\tf_gpu\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\sanjo\Anaconda3\envs\tf_gpu\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can separate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.240s...
# [t-SNE] Computed neighbors for 7352 samples in 37.106s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.035s
# [t-SNE] Iteration 50: error = 124.7009811, gradient norm = 0.0273297 (50 iterations in 8.423s)
# [t-SNE] Iteration 100: error = 107.4310989, gradient norm = 0.0280247 (50 iterations in 4.431s)
# [t-SNE] Iteration 150: error = 101.2028427, gradient norm = 0.0223606 (50 iterations in 2.904s)
# [t-SNE] Iteration 200: error = 97.7471924, gradient norm = 0.0182674 (50 iterations in 2.575s)
# [t-SNE] Iteration 250: error = 95.3846817, gradient norm = 0.0142323 (50 iterations in 2.679s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.384682
# [t-SNE] Iteration 300: error = 4.1224279, gradient norm = 0.0015631 (50 iterations in 2.323s)
# [t-SNE] Iteration 350: error = 3.2120976, gradient norm = 0.0010120 (50 iterations in 2.131s)
# [t-SNE] Iteration 400: error = 2.7831132, gradient norm = 0.0007154 (50 iterations in 2.153s)
# [t-SNE] Iteration 450: error = 2.5184615, gradient norm = 0.0005711 (50 iterations in 2.144s)
# [t-SNE] Iteration 500: error = 2.3353050, gradient norm = 0.0004772 (50 iterations in 2.189s)
# [t-SNE] Iteration 550: error = 2.1967399, gradient norm = 0.0004151 (50 iterations in 2.220s)
# [t-SNE] Iteration 600: error = 2.0875633, gradient norm = 0.0003654 (50 iterations in 2.230s)
# [t-SNE] Iteration 650: error = 1.9975599, gradient norm = 0.0003317 (50 iterations in 2.199s)
# [t-SNE] Iteration 700: error = 1.9220817, gradient norm = 0.0003008 (50 iterations in 2.300s)
# [t-SNE] Iteration 750: error = 1.8571645, gradient norm = 0.0002786 (50 iterations in 2.390s)
# [t-SNE] Iteration 800: error = 1.8005955, gradient norm = 0.0002553 (50 iterations in 2.260s)
# [t-SNE] Iteration 850: error = 1.7505158, gradient norm = 0.0002370 (50 iterations in 2.248s)
# [t-SNE] Iteration 900: error = 1.7057183, gradient norm = 0.0002262 (50 iterations in 2.250s)
# [t-SNE] Iteration 950: error = 1.6656959, gradient norm = 0.0002130 (50 iterations in 2.321s)
# [t-SNE] Iteration 1000: error = 1.6292994, gradient norm = 0.0002001 (50 iterations in 2.406s)
# [t-SNE] KL divergence after 1000 iterations: 1.629299
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.250s...
# [t-SNE] Computed neighbors for 7352 samples in 37.147s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.047s
# [t-SNE] Iteration 50: error = 113.9054413, gradient norm = 0.0249209 (50 iterations in 6.498s)
# [t-SNE] Iteration 100: error = 97.1749115, gradient norm = 0.0139699 (50 iterations in 2.547s)
# [t-SNE] Iteration 150: error = 93.1478577, gradient norm = 0.0085952 (50 iterations in 2.258s)
# [t-SNE] Iteration 200: error = 91.2128067, gradient norm = 0.0076076 (50 iterations in 2.176s)
# [t-SNE] Iteration 250: error = 90.0582581, gradient norm = 0.0050858 (50 iterations in 2.164s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.058258
# [t-SNE] Iteration 300: error = 3.5692878, gradient norm = 0.0014565 (50 iterations in 2.098s)
# [t-SNE] Iteration 350: error = 2.8144000, gradient norm = 0.0007594 (50 iterations in 2.097s)
# [t-SNE] Iteration 400: error = 2.4347584, gradient norm = 0.0005222 (50 iterations in 2.113s)
# [t-SNE] Iteration 450: error = 2.2179890, gradient norm = 0.0004070 (50 iterations in 2.095s)
# [t-SNE] Iteration 500: error = 2.0736017, gradient norm = 0.0003314 (50 iterations in 2.118s)
# [t-SNE] Iteration 550: error = 1.9684579, gradient norm = 0.0002847 (50 iterations in 2.108s)
# [t-SNE] Iteration 600: error = 1.8872854, gradient norm = 0.0002455 (50 iterations in 2.143s)
# [t-SNE] Iteration 650: error = 1.8220571, gradient norm = 0.0002238 (50 iterations in 2.125s)
# [t-SNE] Iteration 700: error = 1.7685070, gradient norm = 0.0001970 (50 iterations in 2.137s)
# [t-SNE] Iteration 750: error = 1.7232313, gradient norm = 0.0001799 (50 iterations in 2.150s)
# [t-SNE] Iteration 800: error = 1.6844537, gradient norm = 0.0001664 (50 iterations in 2.151s)
# [t-SNE] Iteration 850: error = 1.6504884, gradient norm = 0.0001539 (50 iterations in 2.165s)
# [t-SNE] Iteration 900: error = 1.6204261, gradient norm = 0.0001435 (50 iterations in 2.203s)
# [t-SNE] Iteration 950: error = 1.5940665, gradient norm = 0.0001348 (50 iterations in 2.176s)
# [t-SNE] Iteration 1000: error = 1.5705817, gradient norm = 0.0001261 (50 iterations in 2.170s)
# [t-SNE] KL divergence after 1000 iterations: 1.570582
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.224s...
# [t-SNE] Computed neighbors for 7352 samples in 37.817s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.087s
# [t-SNE] Iteration 50: error = 105.6116562, gradient norm = 0.0245402 (50 iterations in 3.804s)
# [t-SNE] Iteration 100: error = 90.6939545, gradient norm = 0.0105573 (50 iterations in 2.626s)
# [t-SNE] Iteration 150: error = 87.5189590, gradient norm = 0.0053299 (50 iterations in 2.252s)
# [t-SNE] Iteration 200: error = 86.2869110, gradient norm = 0.0036240 (50 iterations in 2.187s)
# [t-SNE] Iteration 250: error = 85.5690308, gradient norm = 0.0033425 (50 iterations in 2.202s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.569031
# [t-SNE] Iteration 300: error = 3.1386199, gradient norm = 0.0013879 (50 iterations in 2.250s)
# [t-SNE] Iteration 350: error = 2.4943323, gradient norm = 0.0006451 (50 iterations in 2.152s)
# [t-SNE] Iteration 400: error = 2.1752343, gradient norm = 0.0004226 (50 iterations in 2.204s)
# [t-SNE] Iteration 450: error = 1.9914095, gradient norm = 0.0003121 (50 iterations in 2.202s)
# [t-SNE] Iteration 500: error = 1.8733463, gradient norm = 0.0002514 (50 iterations in 2.206s)
# [t-SNE] Iteration 550: error = 1.7900214, gradient norm = 0.0002115 (50 iterations in 2.265s)
# [t-SNE] Iteration 600: error = 1.7274103, gradient norm = 0.0001806 (50 iterations in 2.241s)
# [t-SNE] Iteration 650: error = 1.6783657, gradient norm = 0.0001610 (50 iterations in 2.389s)
# [t-SNE] Iteration 700: error = 1.6388232, gradient norm = 0.0001446 (50 iterations in 2.300s)
# [t-SNE] Iteration 750: error = 1.6063114, gradient norm = 0.0001312 (50 iterations in 2.328s)
# [t-SNE] Iteration 800: error = 1.5788208, gradient norm = 0.0001196 (50 iterations in 2.351s)
# [t-SNE] Iteration 850: error = 1.5553029, gradient norm = 0.0001097 (50 iterations in 2.346s)
# [t-SNE] Iteration 900: error = 1.5351243, gradient norm = 0.0001030 (50 iterations in 2.319s)
# [t-SNE] Iteration 950: error = 1.5174435, gradient norm = 0.0000966 (50 iterations in 2.318s)
# [t-SNE] Iteration 1000: error = 1.5020113, gradient norm = 0.0000910 (50 iterations in 2.331s)
# [t-SNE] KL divergence after 1000 iterations: 1.502011
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.217s...
# [t-SNE] Computed neighbors for 7352 samples in 38.353s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.167s
# [t-SNE] Iteration 50: error = 97.9553604, gradient norm = 0.0148759 (50 iterations in 4.451s)
# [t-SNE] Iteration 100: error = 83.9154205, gradient norm = 0.0065481 (50 iterations in 2.929s)
# [t-SNE] Iteration 150: error = 81.8443832, gradient norm = 0.0037420 (50 iterations in 2.580s)
# [t-SNE] Iteration 200: error = 81.1372528, gradient norm = 0.0023721 (50 iterations in 2.611s)
# [t-SNE] Iteration 250: error = 80.7625580, gradient norm = 0.0016554 (50 iterations in 2.588s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.762558
# [t-SNE] Iteration 300: error = 2.6970558, gradient norm = 0.0013105 (50 iterations in 2.694s)
# [t-SNE] Iteration 350: error = 2.1619067, gradient norm = 0.0005812 (50 iterations in 2.480s)
# [t-SNE] Iteration 400: error = 1.9128824, gradient norm = 0.0003486 (50 iterations in 2.425s)
# [t-SNE] Iteration 450: error = 1.7661738, gradient norm = 0.0002475 (50 iterations in 2.389s)
# [t-SNE] Iteration 500: error = 1.6724074, gradient norm = 0.0001926 (50 iterations in 2.378s)
# [t-SNE] Iteration 550: error = 1.6084784, gradient norm = 0.0001580 (50 iterations in 2.413s)
# [t-SNE] Iteration 600: error = 1.5617663, gradient norm = 0.0001345 (50 iterations in 2.396s)
# [t-SNE] Iteration 650: error = 1.5265788, gradient norm = 0.0001184 (50 iterations in 2.411s)
# [t-SNE] Iteration 700: error = 1.4996866, gradient norm = 0.0001040 (50 iterations in 2.395s)
# [t-SNE] Iteration 750: error = 1.4781862, gradient norm = 0.0000987 (50 iterations in 2.422s)
# [t-SNE] Iteration 800: error = 1.4611216, gradient norm = 0.0000925 (50 iterations in 2.432s)
# [t-SNE] Iteration 850: error = 1.4476618, gradient norm = 0.0000855 (50 iterations in 2.410s)
# [t-SNE] Iteration 900: error = 1.4365225, gradient norm = 0.0000806 (50 iterations in 2.470s)
# [t-SNE] Iteration 950: error = 1.4273583, gradient norm = 0.0000771 (50 iterations in 2.556s)
# [t-SNE] Iteration 1000: error = 1.4191006, gradient norm = 0.0000763 (50 iterations in 2.582s)
# [t-SNE] KL divergence after 1000 iterations: 1.419101
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.230s...
# [t-SNE] Computed neighbors for 7352 samples in 40.081s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.421s
# [t-SNE] Iteration 50: error = 86.1390076, gradient norm = 0.0242884 (50 iterations in 4.491s)
# [t-SNE] Iteration 100: error = 75.4723892, gradient norm = 0.0052134 (50 iterations in 3.776s)
# [t-SNE] Iteration 150: error = 74.5579147, gradient norm = 0.0029848 (50 iterations in 3.393s)
# [t-SNE] Iteration 200: error = 74.2227936, gradient norm = 0.0017702 (50 iterations in 3.429s)
# [t-SNE] Iteration 250: error = 74.0498199, gradient norm = 0.0011757 (50 iterations in 3.470s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.049820
# [t-SNE] Iteration 300: error = 2.1566172, gradient norm = 0.0011845 (50 iterations in 3.242s)
# [t-SNE] Iteration 350: error = 1.7583274, gradient norm = 0.0004862 (50 iterations in 3.099s)
# [t-SNE] Iteration 400: error = 1.5886238, gradient norm = 0.0002822 (50 iterations in 3.132s)
# [t-SNE] Iteration 450: error = 1.4943272, gradient norm = 0.0001921 (50 iterations in 3.155s)
# [t-SNE] Iteration 500: error = 1.4340883, gradient norm = 0.0001414 (50 iterations in 3.224s)
# [t-SNE] Iteration 550: error = 1.3927931, gradient norm = 0.0001140 (50 iterations in 3.241s)
# [t-SNE] Iteration 600: error = 1.3634578, gradient norm = 0.0000957 (50 iterations in 3.252s)
# [t-SNE] Iteration 650: error = 1.3423131, gradient norm = 0.0000837 (50 iterations in 3.102s)
# [t-SNE] Iteration 700: error = 1.3265409, gradient norm = 0.0000748 (50 iterations in 3.223s)
# [t-SNE] Iteration 750: error = 1.3146552, gradient norm = 0.0000716 (50 iterations in 3.362s)
# [t-SNE] Iteration 800: error = 1.3057433, gradient norm = 0.0000688 (50 iterations in 3.197s)
# [t-SNE] Iteration 850: error = 1.2988744, gradient norm = 0.0000610 (50 iterations in 3.332s)
# [t-SNE] Iteration 900: error = 1.2933099, gradient norm = 0.0000566 (50 iterations in 3.343s)
# [t-SNE] Iteration 950: error = 1.2886209, gradient norm = 0.0000559 (50 iterations in 3.253s)
# [t-SNE] Iteration 1000: error = 1.2847033, gradient norm = 0.0000539 (50 iterations in 3.236s)
# [t-SNE] KL divergence after 1000 iterations: 1.284703
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# > * __We can see that even with different perplexities, all the different Activity names are clustered pretty well, except 2, 'STANDING ' and 'SITTING'. __
